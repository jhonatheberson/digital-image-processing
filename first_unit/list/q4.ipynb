# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
gx = np.matrix('-1 -2 -1;0 0 0;1 2 1')
print(gx)
# Out:
# [[-1 -2 -1]
#  [ 0  0  0]
#  [ 1  2  1]]

# %%
gy=np.matrix('-1 0 1;-2 0 2;-1 0 1')
print(gy)
# Out:
# [[-1  0  1]
#  [-2  0  2]
#  [-1  0  1]]

# %%
img = cv.imread("./Figura_4.png",0)

if img is None: #checks picture has been apened 
    sys.exit("Could not read the image.")

print(img.shape)
plt.subplot(231),plt.imshow(img, 'gray'),plt.title('ORIGINAL')
plt.show()
# Out:
# (113, 116)

# %%
U = cv.filter2D(img,-1, gx)
plt.subplot(121),plt.imshow(U),plt.title('filter')
plt.show()
V = cv.filter2D(img,-1, gy)
plt.subplot(121),plt.imshow(V),plt.title('filter')
plt.show()

# %%
X = np.arange(0, 116, 1)
Y = np.arange(0, 113, 1)
plt.quiver(X, Y,U, V, color='0.5')
# U, V = np.meshgrid(X, Y)
# fig, ax = plt.subplots()
# q = ax.quiver(X, Y, U, V, color='0.5')
# ax.quiverkey(q, X=0.3, Y=1.1, U=10,
#              label='Quiver key, length = 10', labelpos='E')

plt.savefig('fields.png')
plt.show()

# %%
g = abs(gx) + abs(gy)
G = cv.filter2D(img,kernel=g, ddepth=-1)
plt.subplot(121),plt.imshow(G),plt.title('filter_sobel')
plt.savefig('img_sobel.png')
plt.show()
